# %%
import pandas as pd
from pandas import DataFrame
import seaborn_qqplot as sqp

import os

import warnings
warnings.filterwarnings("ignore")

# %%
# the pwd assignment is needed for using it via docker.
# absolute path as interpreted by the container has to be specified
pwd: str = os.environ['HOME'] + '/work/assignment/assignment-2'

# %% [markdown]
# #### Read dataset from file

# %%
master: DataFrame = pd.read_csv(pwd + '/Exam Anxiety.txt', delimiter='\t', header='infer')
print(master.shape)
# Out:
# (103, 5)

# %%
sqp.qqplot(data=master, x='Exam', y='Anxiety', height=4, aspect=1.5, display_kws={'identity': True, 'fit': True})
